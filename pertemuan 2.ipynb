# %%
import numpy as np
import pandas as pd
import nltk
import json
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
# Load JSON data
with open('Data_New.json', encoding='utf-8') as content:
    data1 = json.load(content)
df = pd.DataFrame(data1["intents"])

# %%
df
# Out:
#                                                 tag  \
# 0                                          greeting
# 1                                            Unibot
# 2                                   pencipta_Unibot
# 3                                           goodbye
# 4                              Kampus_Jakarta_Pusat
# ..                                              ...
# 678              Link_Website_Universitas_Cakrawala
# 679             Program_Studi_Universitas_Cakrawala
# 680  Akreditasi_Program_Studi_Universitas_Cakrawala
# 681            Latar_Belakang_Universitas_Cakrawala
# 682                  Beasiswa_Universitas_Cakrawala
#
#                                               patterns  \
# 0    [hallo, hai, halo, hei, hi, hy, pagi, morning,...
# 1                     [Apa itu Unibot?, Siapa Unibot?]
# 2    [Siapa pembuatmu?, Unibot, yang buat kamu siap...
# 3    [Dah, Dadah, Bye, Byee, Good bye, Selamat ting...
# 4    [Kampus yang berada di Jakarta Pusat?, Univers...
# ..                                                 ...
# 678  [Apa website resmi Universitas Cakrawala?, Web...
# 679  [Program studi apa saja di Universitas Cakrawa...
# 680  [Apa akreditasi masing-masing program studi di...
# 681  [Apa latar belakang dari Universitas Cakrawala...
# 682  [Ada beasiswa apa di Universitas Cakrawala?, B...
#
#                                              responses
# 0    [Hai! Unibot di sini. Mau tau informasi tentan...
# 1    [Unibot adalah aplikasi chatbot informasi tent...
# 2    [UnibotBot diciptakan oleh mahasiswa dan mahas...
# 3    [Bye!, Dadahh!, Good bye!, Dahh, semoga harimu...
# 4    [Beberapa universitas di Jakarta Pusat antara ...
# ..                                                 ...
# 678                              [www.cakrawala.ac.id]
# 679  [Bahasa Inggris, Bisnis Digital, Ekonomi Keuan...
# 680                           [-, -, -, -, -, -, -, -]
# 681  [Tentang Universitas Cakrawala Universitas Cak...
# 682                                [memiliki beasiswa]
#
# [683 rows x 3 columns]

# %% [markdown]
# Pemrosessan data

# %%
# Tokenisasi
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['patterns'].tolist() + df['responses'].tolist())
total_words= len(tokenizer.word_index) + 1

# %%
#mengonversi input dan mengatur respons ke urutan token
input_sequences = tokenizer.texts_to_sequences(df['patterns'])
response_sequences = tokenizer.texts_to_sequences(df['responses'])

# %%
#padding bertujuan agar semua memiliki panjang yang sama
max_seq_len = max([len(x) for x in input_sequences + response_sequences])
input_padded = pad_sequences(input_sequences, maxlen=max_seq_len, padding='post')
response_padded = pad_sequences(response_sequences, maxlen=max_seq_len, padding='post')

# %%
# melakukan encoding tags maxlen tentukan sesuai tag
#encoding tags
tag_tokenizer = Tokenizer()
tag_tokenizer.fit_on_texts(df['tag'])
tag_sequences = tag_tokenizer.texts_to_sequences(df['tag'])
tag_padded = pad_sequences(tag_sequences, maxlen=1, padding='post')

# %%
#membangun model LSTM
model = Sequential([
    Embedding(total_words, 128, input_length=max_seq_len),
    LSTM(128, return_sequences=True),
    LSTM(32),
    Dense(32, activation='relu'),
    Dense(len(tag_tokenizer.word_index) + 1, activation='softmax')
])
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summ
200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.8876e-04
# Epoch 149/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 1.0000 - loss: 1.4359e-04
# Epoch 150/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.5709e-04
# Epoch 151/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.3366e-04
# Epoch 152/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.2067e-04
# Epoch 153/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.0818e-04
# Epoch 154/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 9.4507e-05
# Epoch 155/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 8.1838e-05
# Epoch 156/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9968 - loss: 0.0160
# Epoch 157/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9812 - loss: 0.1020
# Epoch 158/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9691 - loss: 0.1362
# Epoch 159/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9882 - loss: 0.0836
# Epoch 160/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9980 - loss: 0.0172
# Epoch 161/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9884 - loss: 0.0629
# Epoch 162/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 8.2688e-04
# Epoch 163/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 6.0283e-04
# Epoch 164/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 4.2067e-04
# Epoch 165/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 4.5056e-04
# Epoch 166/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 3.2530e-04
# Epoch 167/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 2.6043e-04
# Epoch 168/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 2.6330e-04
# Epoch 169/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 2.2138e-04
# Epoch 170/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.9465e-04
# Epoch 171/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.8524e-04
# Epoch 172/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.6890e-04
# Epoch 173/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.0758e-04
# Epoch 174/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.1572e-04
# Epoch 175/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.1458e-04
# Epoch 176/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9959 - loss: 0.0232
# Epoch 177/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9891 - loss: 0.0596
# Epoch 178/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9899 - loss: 0.0343
# Epoch 179/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9680 - loss: 0.1111
# Epoch 180/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9955 - loss: 0.0242
# Epoch 181/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 7.0210e-04
# Epoch 182/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 4.8301e-04
# Epoch 183/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 5.1799e-04
# Epoch 184/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 2.9707e-04
# Epoch 185/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 3.1222e-04
# Epoch 186/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 2.2647e-04
# Epoch 187/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 2.1128e-04
# Epoch 188/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.5998e-04
# Epoch 189/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.6939e-04
# Epoch 190/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.3852e-04
# Epoch 191/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 1.2751e-04
# Epoch 192/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 9.1276e-05
# Epoch 193/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 8.7757e-05
# Epoch 194/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 7.0247e-05
# Epoch 195/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 7.2239e-05
# Epoch 196/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 6.3151e-05
# Epoch 197/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 1.0000 - loss: 6.4065e-05
# Epoch 198/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9984 - loss: 0.0168
# Epoch 199/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9868 - loss: 0.0508
# Epoch 200/200
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9798 - loss: 0.1037

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 15, 128)        │       237,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 15, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 135)            │         4,455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,583 (4.53 MB)
#  Trainable params: 395,527 (1.51 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 791,056 (3.02 MB)

# %%
# untuk megnhasilkan respon
def generate_response(text):
    sequences = tokenizer.texts_to_sequences([text])
    padded =  pad_sequences(sequences,maxlen=max_seq_len, padding='post')
    predicted = model.predict(padded, verbose=0)
    tag = tag_tokenizer.index_word[np.argmax(predicted)]

    response = df[df['tag'] == tag]['responses'].values
    return np.random.choice(response)

# %%
model.save('chatbot_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# simpan tokenisasi
import pickle

with open ('tokenizer.pickle','wb') as handle:
    pickle.dump(tokenizer,handle,protocol=pickle.HIGHEST_PROTOCOL)
with open ('tag_tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer,handle,protocol=pickle.HIGHEST_PROTOCOL)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(input_padded, tag_padded, test_size=0.2, random_state=42)

model = Sequential([
    Embedding(total_words, 128, input_length=max_seq_len),
    LSTM(128, return_sequences=True),
    LSTM(64),
    Dense(64, activation='relu'),
    Dense(len(tag_tokenizer.word_index) + 1, activation='softmax')
])
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Melatih model
model.fit(X_train, y_train, epochs=200, batch_size=2, verbose=1)
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.1076 - loss: 4.4872
# Epoch 2/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.1220 - loss: 3.9381
# Epoch 3/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1056 - loss: 3.8811
# Epoch 4/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1122 - loss: 3.7053
# Epoch 5/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1215 - loss: 3.6974
# Epoch 6/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.1389 - loss: 3.3172
# Epoch 7/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.
200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 1.0000 - loss: 2.9924e-05
# Epoch 161/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 1.0000 - loss: 2.9440e-05
# Epoch 162/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 2.2342e-05
# Epoch 163/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 1.9170e-05
# Epoch 164/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 1.7690e-05
# Epoch 165/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9517 - loss: 0.3562
# Epoch 166/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9348 - loss: 0.2929
# Epoch 167/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9594 - loss: 0.3985
# Epoch 168/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9667 - loss: 0.1278
# Epoch 169/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9883 - loss: 0.0553
# Epoch 170/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9908 - loss: 0.0890
# Epoch 171/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9909 - loss: 0.0271
# Epoch 172/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9965 - loss: 0.0449
# Epoch 173/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 174/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 1.0000 - loss: 7.5247e-04
# Epoch 175/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 5.5933e-04
# Epoch 176/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 4.9511e-04
# Epoch 177/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 1.0000 - loss: 4.5658e-04
# Epoch 178/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 3.5120e-04
# Epoch 179/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 3.4262e-04
# Epoch 180/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 2.7630e-04
# Epoch 181/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 3.5316e-04
# Epoch 182/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 2.2069e-04
# Epoch 183/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 2.3677e-04
# Epoch 184/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 2.0110e-04
# Epoch 185/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 1.8389e-04
# Epoch 186/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 1.7521e-04
# Epoch 187/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 1.5913e-04
# Epoch 188/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 1.0000 - loss: 1.2079e-04
# Epoch 189/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 1.2309e-04
# Epoch 190/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 1.0000 - loss: 9.4485e-05
# Epoch 191/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 1.0000 - loss: 8.2383e-05
# Epoch 192/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 9.5153e-05
# Epoch 193/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 6.8410e-05
# Epoch 194/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 6.8087e-05
# Epoch 195/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 5.5249e-05
# Epoch 196/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 5.1820e-05
# Epoch 197/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 5.3177e-05
# Epoch 198/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 4.0104e-05
# Epoch 199/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 1.0000 - loss: 3.6766e-05
# Epoch 200/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 3.7070e-05

# %%
from sklearn.metrics import classification_report
# Memprediksi tag untuk data uji
predictions = model.predict(X_test)
predicted_tags = [np.argmax(pred) for pred in predictions]
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step

# %%
import numpy as np
from sklearn.metrics import classification_report

# Memprediksi tag untuk data uji
predictions = model.predict(X_test)

# Mengonversi prediksi menjadi tag
predicted_tags = [np.argmax(pred) for pred in predictions]

# Menentukan kelas yang ada dalam y_test
unique_classes = np.unique(y_test)

# Menghasilkan laporan klasifikasi dengan nama target sesuai kelas yang ada
report = classification_report(y_test, predicted_tags,
                            target_names=list(tag_tokenizer.word_index.keys()),
                            zero_division=0)
print(report)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 14
#      11 unique_classes = np.unique(y_test)
#      13 # Menghasilkan laporan klasifikasi dengan nama target sesuai kelas yang ada
# ---> 14 report = classification_report(y_test, predicted_tags,
#      15                             target_names=list(tag_tokenizer.word_index.keys()),
#      16                             zero_division=0)
#      17 print(report)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:2648, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2642         warnings.warn(
#    2643             "labels size, {0}, does not match size of target_names, {1}".format(
#    2644                 len(labels), len(target_names)
#    2645             )
#    2646         )
#    2647     else:
# -> 2648         raise ValueError(
#    2649             "Number of classes, {0}, does not match size of "
#    2650             "target_names, {1}. Try specifying the labels "
#    2651             "parameter".format(len(labels), len(target_names))
#    2652         )
#    2653 if target_names is None:
#    2654     target_names = ["%s" % l for l in labels]
#
# ValueError: Number of classes, 51, does not match size of target_names, 134. Try specifying the labels parameter

# %%
print("Ukuran y_test_labels:", y_test_labels.shape)
print("Ukuran predicted_labels:", predicted_labels.shape)
# Out:
# Ukuran y_test_labels: (137,)
# Ukuran predicted_labels: (18495,)
